# %%
# %cd /content/drive/MyDrive/Pandas101/Pandas101
# Out:
# /content/drive/MyDrive/Pandas101/Pandas101

# %%
# !git remote add correction https://github.com/Barakamtana/Pandas101.git
# !git remote -v
# Out:
# error: remote correction already exists.
# correction	https://github.com/Barakamtana/Pandas101.git (fetch)
# correction	https://github.com/Barakamtana/Pandas101.git (push)
# origin	https://github.com/Barakamtana/Pandas101.git (fetch)
# origin	https://github.com/Barakamtana/Pandas101.git (push)

# %%
# !git remote remove corrrection

# %%
# !git status

# %%
# !git add .

# %%
# !git commit -m "Correction of original code"
# Out:
# [main 17d1ec7] Correction of original code
#  4 files changed, 703 insertions(+), 234193 deletions(-)
#  create mode 100644 Absenteeism-data.csv
#  create mode 100644 Pandas_Project (1).ipynb
#  delete mode 100644 Pandas_Project.ipynb
#  create mode 100644 git_commands.ipynb

# %%
# !git push -u corrrection main
# Out:
# fatal: unable to access 'https://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github.com/Barakamtana/Pandas101.git/': Could not resolve host: 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github.com
